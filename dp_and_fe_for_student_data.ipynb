# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import warnings
warnings.filterwarnings('ignore')

# %%
df_master = pd.read_csv('student.csv')

# %%
print("📌 ก่อนการปรับปรุงข้อมูล")
display(df_master.head(10))
# Out:
# 📌 ก่อนการปรับปรุงข้อมูล
#    รหัสนักศึกษา      ชื่อ   อายุ   เพศ             คณะ   GPA  ส่วนสูง_cm  \
# 0         64001     สมชาย   20.0   ชาย     วิทยาศาสตร์  3.21       170.0
# 1         64002    สมหญิง   21.0  หญิง           วิทย์  3.45       165.0
# 2         64003       NaN    NaN  Male         Science  3.67       175.0
# 3         64004  สมศักดิ์   22.0     ช  คณะวิทยาศาสตร์ -1.00       168.0
# 4         64005      สมใจ   19.0     ญ           วิศวะ  3.89       160.0
# 5         64006     กานต์  150.0   ชาย     Engineering  3.12       172.0
# 6         64007     กิตติ   21.0  หญิง        วิศวกรรม  4.50       158.0
# 7         64008      จิรา   20.0     F      ศิลปศาสตร์  2.98       180.0
# 8         64009    ชนาธิป   23.0     M            Arts  3.34       163.0
# 9         64010      ดารา   21.0  หญิง           ศิลป์  3.56       167.0
#
#    น้ำหนัก_kg  ชั่วโมงเรียน_ต่อสัปดาห์ วันที่ลงทะเบียน
# 0        65.0                     15.0      2024-01-24
# ...

# %%
# ลบหรือแทนค่าชื่อที่หายไป
df_master['ชื่อ'] = df_master['ชื่อ'].fillna('ไม่ระบุ')

# แทนค่าอายุที่หายไปด้วยค่าเฉลี่ย
df_master['อายุ'] = df_master['อายุ'].fillna(df_master['อายุ'].mean())

# ลบค่า GPA ที่เป็นค่าผิดปกติ (เช่น -1) และแทนด้วยค่าเฉลี่ย
df_master.loc[df_master['GPA'] < 0, 'GPA'] = None
df_master['GPA'] = df_master['GPA'].fillna(df_master['GPA'].mean())

# รวมค่าที่เขียนต่างกันให้เหมือนกัน
df_master['เพศ'] = df_master['เพศ'].replace({
    'ชาย': 'ชาย', 'ช': 'ชาย', 'Male': 'ชาย',
    'หญิง': 'หญิง', 'ญ': 'หญิง', 'Female': 'หญิง'
})

# เติมค่า Missing ของส่วนสูงและน้ำหนัก (ถ้ามี)
df_master['น้ำหนัก_kg'] = df_master['น้ำหนัก_kg'].fillna(df_master['น้ำหนัก_kg'].mean())
df_master['ส่วนสูง_cm'] = df_master['ส่วนสูง_cm'].fillna(df_master['ส่วนสูง_cm'].mean())

# %%
# คำนวณ BMI
df_master['BMI'] = df_master['น้ำหนัก_kg'] / ((df_master['ส่วนสูง_cm'] / 100) ** 2)

# แปลงวันที่เป็น datetime และแยกเดือน/ปี
df_master['วันที่ลงทะเบียน'] = pd.to_datetime(df_master['วันที่ลงทะเบียน'])
df_master['เดือนลงทะเบียน'] = df_master['วันที่ลงทะเบียน'].dt.month
df_master['ปีลงทะเบียน'] = df_master['วันที่ลงทะเบียน'].dt.year

# ---------------- แสดงข้อมูลหลังการเปลี่ยนแปลง ----------------
print("\n✅ หลังการปรับปรุงข้อมูล")
display(df_master.head(10))
# Out:
# ✅ หลังการปรับปรุงข้อมูล
#    รหัสนักศึกษา      ชื่อ        อายุ   เพศ             คณะ       GPA  \
# 0         64001     สมชาย   20.000000   ชาย     วิทยาศาสตร์  3.210000
# 1         64002    สมหญิง   21.000000  หญิง           วิทย์  3.450000
# 2         64003   ไม่ระบุ   28.470588   ชาย         Science  3.670000
# 3         64004  สมศักดิ์   22.000000   ชาย  คณะวิทยาศาสตร์  3.495882
# 4         64005      สมใจ   19.000000  หญิง           วิศวะ  3.890000
# 5         64006     กานต์  150.000000   ชาย     Engineering  3.120000
# 6         64007     กิตติ   21.000000  หญิง        วิศวกรรม  4.500000
# 7         64008      จิรา   20.000000     F      ศิลปศาสตร์  2.980000
# 8         64009    ชนาธิป   23.000000     M            Arts  3.340000
# 9         64010      ดารา   21.000000  หญิง           ศิลป์  3.560000
#
#    ส่วนสูง_cm  น้ำหนัก_kg  ชั่วโมงเรียน_ต่อสัปดาห์ วันที่ลงทะเบียน        BMI  \
# 0       170.0   65.000000                     15.0      2024-01-24  22.491349
# ...
